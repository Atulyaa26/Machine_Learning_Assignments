# %%
## Data Analysis libraries
import pandas as pd
import numpy as np

## Data Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

## Ignore warnings libraries
import warnings 
warnings.filterwarnings('ignore')

# %%
url = "https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/house_rental_data.csv.txt"
df = pd.read_csv(url)

# %% [markdown]
# ## Use pandas to get some insights into the data

# %%
df.head()
# Out:
#    Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 0           1  1177.698      2           7        2            2         2
# 1           2  2134.800      5           7        4            2         2
# 2           3  1138.560      5           7        2            2         1
# 3           4  1458.780      2           7        3            2         2
# 4           5   967.776     11          14        3            2         2
#
#    Price
# 0  62000
# 1  78000
# 2  58000
# 3  45000
# 4  45000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sqft', 'Floor', 'TotalFloor', 'Bedroom', 'Living.Room',
#        'Bathroom', 'Price'],
#       dtype='object')

# %%
df.reset_index(drop = True)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.tail()
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  Price
# 640  1359.156      7          15        3            2         2  45000
# 641   377.148      4          10        1            1         1  24800
# 642   740.064     13          14        1            1         1  45000
# 643  1707.840      3          14        3            2         2  65000
# 644  1376.946      6           7        3            2         1  36000

# %%
df.dtypes
# Out:
# Sqft           float64
# Floor            int64
# TotalFloor       int64
# Bedroom          int64
# Living.Room      int64
# Bathroom         int64
# Price            int64
# dtype: object

# %%
df.describe()
# Out:
#               Sqft       Floor  TotalFloor     Bedroom  Living.Room  \
# count   645.000000  645.000000  645.000000  645.000000   645.000000
# mean   1527.656260    5.939535   10.855814    2.837209     1.813953
# std     767.386531    3.884721    4.996208    1.010740     0.462364
# min     359.358000    1.000000    1.000000    1.000000     0.000000
# 25%     925.080000    3.000000    7.000000    2.000000     2.000000
# 50%    1423.200000    5.000000   12.000000    3.000000     2.000000
# 75%    1892.856000    8.000000   14.000000    4.000000     2.000000
# max    5856.468000   22.000000   38.000000    7.000000     4.000000
#
#          Bathroom          Price
# count  645.000000     645.000000
# mean     1.810853   61986.823256
# std      0.683574   35635.091007
# min      0.000000    6100.000000
# 25%      1.000000   39000.000000
# 50%      2.000000   50000.000000
# 75%      2.000000   75000.000000
# max      5.000000  250000.000000

# %%
print('The no of columns and rows : ',df.shape)
print('The size of the dataset : ',df.size)
# Out:
# The no of columns and rows :  (645, 7)
# The size of the dataset :  4515

# %%
df = df.rename(columns={'Living.Room':'Living_Room'})
df.head()
# Out:
#        Sqft  Floor  TotalFloor  Bedroom  Living_Room  Bathroom  Price
# 0  1177.698      2           7        2            2         2  62000
# 1  2134.800      5           7        4            2         2  78000
# 2  1138.560      5           7        2            2         1  58000
# 3  1458.780      2           7        3            2         2  45000
# 4   967.776     11          14        3            2         2  45000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sqft         645 non-null    float64
#  1   Floor        645 non-null    int64
#  2   TotalFloor   645 non-null    int64
#  3   Bedroom      645 non-null    int64
#  4   Living_Room  645 non-null    int64
#  5   Bathroom     645 non-null    int64
#  6   Price        645 non-null    int64
# dtypes: float64(1), int64(6)
# memory usage: 35.4 KB

# %%
df.isnull().count()
# Out:
# Sqft           645
# Floor          645
# TotalFloor     645
# Bedroom        645
# Living_Room    645
# Bathroom       645
# Price          645
# dtype: int64

# %%
df.value_counts()
# Out:
# Sqft      Floor  TotalFloor  Bedroom  Living_Room  Bathroom  Price
# 1700.724  13     21          2        2            2         55000     5
# 1889.298  2      14          4        2            2         100000    4
# 2052.966  5      7           4        2            2         78000     4
# 796.992   3      12          2        2            2         45000     3
# 2067.198  4      14          4        2            2         100000    3
#                                                                       ..
# 1138.560  3      4           3        2            2         40000     1
# 1135.002  2      7           3        2            1         37000     1
# 1127.886  11     12          4        2            2         148000    1
#                              3        2            2         150000    1
# 5856.468  7      21          6        2            5         180000    1
# Length: 579, dtype: int64

# %% [markdown]
# ## Show some interesting visualization of the data

# %%
df.columns
# Out:
# Index(['Sqft', 'Floor', 'TotalFloor', 'Bedroom', 'Living_Room', 'Bathroom',
#        'Price'],
#       dtype='object')

# %%
sns.barplot(y=df['Sqft'],x=df['TotalFloor'])
# Out:
# <Axes: xlabel='TotalFloor', ylabel='Sqft'>

# %%
sns.scatterplot(y=df['Sqft'],x=df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Sqft'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.lineplot(y=df['Sqft'],x=df['Bathroom'])
# Out:
# <Axes: xlabel='Bathroom', ylabel='Sqft'>

# %%
sns.distplot(x=df['Living_Room'])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.pairplot(data=df)

# %%
sns.violinplot(y=df['Sqft'],x=df['Bedroom'])
# Out:
# <Axes: xlabel='Bedroom', ylabel='Sqft'>

# %%
sns.kdeplot(df['Floor'])
# Out:
# <Axes: xlabel='Floor', ylabel='Density'>

# %%
sns.jointplot(x='TotalFloor',y='Price',data=df,kind='scatter')

# %%
sns.regplot(y=df['Price'],x=df['Bedroom'])
# Out:
# <Axes: xlabel='Bedroom', ylabel='Price'>

# %% [markdown]
# ## Manage data for training & testing

# %%
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics

# %%
df.head()
# Out:
#        Sqft  Floor  TotalFloor  Bedroom  Living_Room  Bathroom  Price
# 0  1177.698      2           7        2            2         2  62000
# 1  2134.800      5           7        4            2         2  78000
# 2  1138.560      5           7        2            2         1  58000
# 3  1458.780      2           7        3            2         2  45000
# 4   967.776     11          14        3            2         2  45000

# %%
X = df.drop(labels = ['Price'] , axis = 1)
y = df['Price']

# %%
X
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Living_Room  Bathroom
# 0    1177.698      2           7        2            2         2
# 1    2134.800      5           7        4            2         2
# 2    1138.560      5           7        2            2         1
# 3    1458.780      2           7        3            2         2
# 4     967.776     11          14        3            2         2
# ..        ...    ...         ...      ...          ...       ...
# 640  1359.156      7          15        3            2         2
# 641   377.148      4          10        1            1         1
# 642   740.064     13          14        1            1         1
# 643  1707.840      3          14        3            2         2
# 644  1376.946      6           7        3            2         1
#
# [645 rows x 6 columns]

# %%
y
# Out:
# 0      62000
# 1      78000
# 2      58000
# 3      45000
# 4      45000
#        ...
# 640    45000
# 641    24800
# 642    45000
# 643    65000
# 644    36000
# Name: Price, Length: 645, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
scaler = MinMaxScaler(feature_range = (0,1))
X_train_scaled = scaler.fit_transform(X_train)
X_train = pd.DataFrame(X_train_scaled)

X_test_scaled = scaler.fit_transform(X_test)
X_test = pd.DataFrame(X_test_scaled)

# %%
from sklearn import neighbors
from sklearn.metrics import mean_squared_error 
from math import sqrt
from sklearn.neighbors import KNeighborsClassifier

# %%
rmse = []
for k in range(1,21):
    knn = neighbors.KNeighborsRegressor(n_neighbors = k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    error = sqrt(mean_squared_error(y_test,y_pred))
    rmse.append(error)
    
    print('RMSE for k =',k,'is',error)
# Out:
# RMSE for k = 1 is 20919.124131990142
# RMSE for k = 2 is 19710.702616390492
# RMSE for k = 3 is 18725.995552066666
# RMSE for k = 4 is 18974.582246284823
# RMSE for k = 5 is 18188.543948167444
# RMSE for k = 6 is 18038.261770584613
# RMSE for k = 7 is 17993.932341388594
# RMSE for k = 8 is 18202.244255470374
# RMSE for k = 9 is 18205.389705570888
# RMSE for k = 10 is 18635.97244652179
# RMSE for k = 11 is 18649.05637970334
# RMSE for k = 12 is 18516.17417485415
# RMSE for k = 13 is 18245.304809922756
# RMSE for k = 14 is 18175.484114994793
# RMSE for k = 15 is 18233.336656555304
# RMSE for k = 16 is 18377.67938809847
# RMSE for k = 17 is 18316.939878953504
# RMSE for k = 18 is 18625.61770589093
# RMSE for k = 19 is 18673.597004416697
# RMSE for k = 20 is 18814.310093723627

# %% [markdown]
# ## Data cleaning & getting rid of irrelevant information before clustering

# %%
df
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Living_Room  Bathroom  Price
# 0    1177.698      2           7        2            2         2  62000
# 1    2134.800      5           7        4            2         2  78000
# 2    1138.560      5           7        2            2         1  58000
# 3    1458.780      2           7        3            2         2  45000
# 4     967.776     11          14        3            2         2  45000
# ..        ...    ...         ...      ...          ...       ...    ...
# 640  1359.156      7          15        3            2         2  45000
# 641   377.148      4          10        1            1         1  24800
# 642   740.064     13          14        1            1         1  45000
# 643  1707.840      3          14        3            2         2  65000
# 644  1376.946      6           7        3            2         1  36000
#
# [645 rows x 7 columns]
